# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
from sklearn import tree

music_data=pd.read_csv('music.csv')
# music_data
X = music_data.drop(columns='genre')
# X
y = music_data['genre']
# y
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.2)

# model=DecisionTreeClassifier()
# model.fit(X_train,y_train) #train data
# predictions = model.predict(X_test)
# print(predictions)
# accuracy_score(y_test,predictions)

# %%
music_data.head()
# Out:
#    age  gender   genre
# 0   20       1  HipHop
# 1   23       1  HipHop
# 2   25       1  HipHop
# 3   26       1    Jazz
# 4   29       1    Jazz

# %%
#train data will save .we can use it next time without train it again
# mdata=DecisionTreeClassifier()
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)
# mdata.fit(X_train,y_train)
# joblib.dump(mdata,'musictrain.joblib')

# %%
##loading trained data
mj=joblib.load('musictrain.joblib')
predictions=mj.predict([[35,0],[25,1]])
predictions
# Out:
# array(['Classical', 'HipHop'], dtype=object)

# %%
# tree.export_graphviz(mdata,out_file='musicTra.dot',
#                      feature_names=['age','gender'],
#                     class_names=sorted(y.unique()),
#                     label='all',
#                     rounded=True,
#                     filled=True)

# %% [markdown]
# # Visualize Tree

# %%
plt.figure(figsize=(10,8))
tree.plot_tree(mj,filled=True)
# Out:
# [Text(348.75, 380.52, 'X[0] <= 30.5\ngini = 0.778\nsamples = 18\nvalue = [3, 6, 3, 3, 3]'),
#  Text(279.0, 271.8, 'X[0] <= 25.5\ngini = 0.75\nsamples = 12\nvalue = [3, 0, 3, 3, 3]'),
#  Text(139.5, 163.07999999999998, 'X[1] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0]'),
#  Text(69.75, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]'),
#  Text(209.25, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]'),
#  Text(418.5, 163.07999999999998, 'X[1] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 0, 3]'),
#  Text(348.75, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]'),
#  Text(488.25, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(418.5, 271.8, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0, 0]')]

# %%
tree.export_text(mj)
# Out:
# '|--- feature_0 <= 30.50\n|   |--- feature_0 <= 25.50\n|   |   |--- feature_1 <= 0.50\n|   |   |   |--- class: Dance\n|   |   |--- feature_1 >  0.50\n|   |   |   |--- class: HipHop\n|   |--- feature_0 >  25.50\n|   |   |--- feature_1 <= 0.50\n|   |   |   |--- class: Acoustic\n|   |   |--- feature_1 >  0.50\n|   |   |   |--- class: Jazz\n|--- feature_0 >  30.50\n|   |--- class: Classical\n'
