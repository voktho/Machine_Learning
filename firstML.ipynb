# %%
print('Voktho')
# Out:
# Voktho

# %%
import pandas as pd
matches=pd.read_csv('WorldCupMatches.csv')

# %%
matches.shape
# Out:
# (4572, 20)

# %%
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
matches
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
matches.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
matches.values
# Out:
# array([[1930.0, '13 Jul 1930 - 15:00 ', 'Group 1', ..., 1096.0, 'FRA',
#         'MEX'],
#        [1930.0, '13 Jul 1930 - 15:00 ', 'Group 4', ..., 1090.0, 'USA',
#         'BEL'],
#        [1930.0, '14 Jul 1930 - 12:45 ', 'Group 2', ..., 1093.0, 'YUG',
#         'BRA'],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
matches.size
# Out:
# 91440

# %%
matches.isna().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
matches.isna()
# Out:
#        Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0     False     False  False    False  False           False            False
# 1     False     False  False    False  False           False            False
# 2     False     False  False    False  False           False            False
# 3     False     False  False    False  False           False            False
# 4     False     False  False    False  False           False            False
# ...     ...       ...    ...      ...    ...             ...              ...
# 4567   True      True   True     True   True            True             True
# 4568   True      True   True     True   True            True             True
# 4569   True      True   True     True   True            True             True
# 4570   True      True   True     True   True            True             True
# 4571   True      True   True     True   True            True             True
#
# ...

# %%
matches.dtypes
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
matches.hist(bins=100,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Home Team Goals'}>,
#         <AxesSubplot:title={'center':'Away Team Goals'}>],
#        [<AxesSubplot:title={'center':'Attendance'}>,
#         <AxesSubplot:title={'center':'Half-time Home Goals'}>,
#         <AxesSubplot:title={'center':'Half-time Away Goals'}>],
#        [<AxesSubplot:title={'center':'RoundID'}>,
#         <AxesSubplot:title={'center':'MatchID'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
home_indanger=matches[matches['Half-time Away Goals']>1]
home_indanger
# Out:
#        Year               Datetime                     Stage  \
# 17   1930.0   30 Jul 1930 - 14:15                      Final
# 19   1934.0   27 May 1934 - 16:30          Preliminary round
# 22   1934.0   27 May 1934 - 16:30          Preliminary round
# 43   1938.0   09 Jun 1938 - 18:00                First round
# 51   1938.0   19 Jun 1938 - 17:00      Match for third place
# 69   1950.0   09 Jul 1950 - 15:00                    Group 6
# 72   1950.0   13 Jul 1950 - 15:00                    Group 6
# 94   1954.0   26 Jun 1954 - 17:00             Quarter-finals
# 100  1954.0   04 Jul 1954 - 17:00                      Final
# 103  1958.0   08 Jun 1958 - 19:00                    Group 1
# 105  1958.0   08 Jun 1958 - 19:00                    Group 2
# 114  1958.0   11 Jun 1958 - 19:00                    Group 1
# 121  1958.0   15 Jun 1958 - 19:00                    Group 2
# 195  1966.0   23 Jul 1966 - 15:00             Quarter-finals
# ...

# %%
matches[['MatchID','Attendance']].plot(kind='scatter',x='MatchID',y='Attendance',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='MatchID', ylabel='Attendance'>

# %%
matches[['MatchID','Year']]
# Out:
#       MatchID    Year
# 0      1096.0  1930.0
# 1      1090.0  1930.0
# 2      1093.0  1930.0
# 3      1098.0  1930.0
# 4      1085.0  1930.0
# ...       ...     ...
# 4567      NaN     NaN
# 4568      NaN     NaN
# 4569      NaN     NaN
# 4570      NaN     NaN
# 4571      NaN     NaN
#
# [4572 rows x 2 columns]

# %%
pd.DataFrame(matches['Attendance'].value_counts())
# Out:
#          Attendance
# 45000.0          13
# 43000.0          13
# 52000.0          11
# 65000.0           9
# 25000.0           8
# ...             ...
# 14903.0           1
# 34976.0           1
# 11665.0           1
# 12217.0           1
# 62010.0           1
#
# [622 rows x 1 columns]

# %%
matches.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
matches.index
# Out:
# RangeIndex(start=0, stop=4572, step=1)

# %%
matches.values
# Out:
# array([[1930.0, '13 Jul 1930 - 15:00 ', 'Group 1', ..., 1096.0, 'FRA',
#         'MEX'],
#        [1930.0, '13 Jul 1930 - 15:00 ', 'Group 4', ..., 1090.0, 'USA',
#         'BEL'],
#        [1930.0, '14 Jul 1930 - 12:45 ', 'Group 2', ..., 1093.0, 'YUG',
#         'BRA'],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
type(matches)
# Out:
# pandas.core.frame.DataFrame

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
matches.loc[2]
# Out:
# Year                                     1930.0
# Datetime                   14 Jul 1930 - 12:45
# Stage                                   Group 2
# Stadium                          Parque Central
# City                                Montevideo
# Home Team Name                       Yugoslavia
# Home Team Goals                             2.0
# Away Team Goals                             1.0
# Away Team Name                           Brazil
# Win conditions
# Attendance                              24059.0
# Half-time Home Goals                        2.0
# Half-time Away Goals                        0.0
# Referee                     TEJADA Anibal (URU)
# Assistant 1             VALLARINO Ricardo (URU)
# Assistant 2                 BALWAY Thomas (FRA)
# RoundID                                   201.0
# MatchID                                  1093.0
# Home Team Initials                          YUG
# Away Team Initials                          BRA
# Name: 2, dtype: object

# %%
matches.iloc[2]
# Out:
# Year                                     1930.0
# Datetime                   14 Jul 1930 - 12:45
# Stage                                   Group 2
# Stadium                          Parque Central
# City                                Montevideo
# Home Team Name                       Yugoslavia
# Home Team Goals                             2.0
# Away Team Goals                             1.0
# Away Team Name                           Brazil
# Win conditions
# Attendance                              24059.0
# Half-time Home Goals                        2.0
# Half-time Away Goals                        0.0
# Referee                     TEJADA Anibal (URU)
# Assistant 1             VALLARINO Ricardo (URU)
# Assistant 2                 BALWAY Thomas (FRA)
# RoundID                                   201.0
# MatchID                                  1093.0
# Home Team Initials                          YUG
# Away Team Initials                          BRA
# Name: 2, dtype: object

# %%
matchesSub=matches.loc[:,['Home Team Name','Away Team Name','Home Team Goals','Away Team Goals']]
matchesSub.head()
# Out:
#   Home Team Name Away Team Name  Home Team Goals  Away Team Goals
# 0         France         Mexico              4.0              1.0
# 1            USA        Belgium              3.0              0.0
# 2     Yugoslavia         Brazil              2.0              1.0
# 3        Romania           Peru              3.0              1.0
# 4      Argentina         France              1.0              0.0

# %%
matches.loc[matches['Home Team Name']=='Brazil']
# Out:
#        Year              Datetime                     Stage  \
# 11   1930.0  20 Jul 1930 - 13:00                    Group 2
# 40   1938.0  05 Jun 1938 - 17:30                First round
# 44   1938.0  12 Jun 1938 - 17:00             Quarter-finals
# 48   1938.0  14 Jun 1938 - 18:00             Quarter-finals
# 51   1938.0  19 Jun 1938 - 17:00      Match for third place
# ..      ...                   ...                       ...
# 827  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 836  2014.0  28 Jun 2014 - 13:00                Round of 16
# 845  2014.0  04 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
#
#                    Stadium             City Home Team Name  Home Team Goals  \
# 11      Estadio Centenario      Montevideo          Brazil              4.0
# 40      Stade de la Meinau      Strasbourg          Brazil              6.0
# ...

# %%
matches.loc[(matches['Home Team Name']=='Brazil') & (matches['Away Team Goals']>matches['Home Team Goals'])]
# Out:
#        Year              Datetime                     Stage  \
# 268  1974.0  06 Jul 1974 - 16:00      Match for third place
# 450  1990.0  24 Jun 1990 - 17:00                Round of 16
# 551  1998.0  23 Jun 1998 - 21:00                    Group A
# 579  1998.0  12 Jul 1998 - 21:00                      Final
# 703  2006.0  01 Jul 2006 - 21:00             Quarter-finals
# 826  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 827  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
#
#                                Stadium             City Home Team Name  \
# 268                     Olympiastadion          Munich          Brazil
# 450                  Stadio delle Alpi           Turin          Brazil
# 551                    Stade V�lodrome      Marseilles          Brazil
# 579                    Stade de France     Saint-Denis          Brazil
# ...

# %%
matches.isna()
# Out:
#        Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0     False     False  False    False  False           False            False
# 1     False     False  False    False  False           False            False
# 2     False     False  False    False  False           False            False
# 3     False     False  False    False  False           False            False
# 4     False     False  False    False  False           False            False
# ...     ...       ...    ...      ...    ...             ...              ...
# 4567   True      True   True     True   True            True             True
# 4568   True      True   True     True   True            True             True
# 4569   True      True   True     True   True            True             True
# 4570   True      True   True     True   True            True             True
# 4571   True      True   True     True   True            True             True
#
# ...

# %%
clean_matches=matches.dropna()
clean_matches
# clean_matches.values
# clean_matches.index
# clean_matches.shape
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
clean_matches.isna().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
clean_matches.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   850.000000       850.000000       850.000000     850.000000
# mean   1985.021176         1.810588         1.022353   45164.800000
# std      22.431301         1.612125         1.088853   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            850.000000            850.000000  8.500000e+02  8.500000e+02
# mean               0.710588              0.429412  1.068626e+07  6.078489e+07
# std                0.937885              0.691752  2.732359e+07  1.105805e+08
# ...

# %%
##outliers
import seaborn as sns
sns.boxplot(x='Attendance',data=clean_matches)
# Out:
# <AxesSubplot:xlabel='Attendance'>

# %%
Q1=clean_matches.quantile(0.25)
Q3=clean_matches.quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# Year                          32.0
# Home Team Goals                2.0
# Away Team Goals                2.0
# Attendance                 31374.5
# Half-time Home Goals           1.0
# Half-time Away Goals           1.0
# RoundID                   249460.0
# MatchID                 43948869.5
# dtype: float64

# %%
players=pd.read_csv('footballers.csv')
players
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
players.isna().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
players.loc[2,'Name']
# Out:
# 'Neymar Jr'

# %%
players.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
print(players.quantile(0.25))
print(players.quantile(0.75))
print(players.quantile(0.95))
# Out:
# Unnamed: 0                    4551.5
# ID                          200315.5
# Age                             21.0
# Overall                         62.0
# Potential                       85.0
# Special                       1457.0
# International Reputation         1.0
# Weak Foot                        3.0
# Skill Moves                      2.0
# Jersey Number                    8.0
# Crossing                        38.0
# Finishing                       30.0
# HeadingAccuracy                 44.0
# ShortPassing                    54.0
# Volleys                         30.0
# Dribbling                       49.0
# Curve                           34.0
# FKAccuracy                      31.0
# LongPassing                     43.0
# BallControl                     54.0
# Acceleration                    57.0
# SprintSpeed                     57.0
# Agility                         55.0
# Reactions                       56.0
# Balance                         56.0
# ...

# %%
import numpy as np
players['Potential']=np.where(players['Potential']<=55,56,players['Potential'])

# %%
players['Potential']
# Out:
# 0        85
# 1        85
# 2        85
# 3        85
# 4        85
#          ..
# 18202    85
# 18203    85
# 18204    85
# 18205    85
# 18206    85
# Name: Potential, Length: 18207, dtype: int32

# %%
import seaborn as sns
sns.boxplot(x='Potential',data=players)
# Out:
# <AxesSubplot:xlabel='Potential'>

# %%
sns.boxplot(x='Penalties',data=players)
# Out:
# <AxesSubplot:xlabel='Penalties'>

# %%
players['Penalties'].describe()
# Out:
# count    18159.000000
# mean        48.548598
# std         15.704053
# min          5.000000
# 25%         39.000000
# 50%         49.000000
# 75%         60.000000
# max         92.000000
# Name: Penalties, dtype: float64

# %%
players['Penalties']=np.where(players['Penalties']>80,50,players['Penalties'])
players['Penalties']
# Out:
# 0        75.0
# 1        50.0
# 2        50.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64

# %%
sns.boxplot(x='Penalties',data=players)
# Out:
# <AxesSubplot:xlabel='Penalties'>
